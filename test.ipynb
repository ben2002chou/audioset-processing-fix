# %%
# !ffmpeg -ss  60 -t 70 -i $(yt-dlp -N 8 -f 'b' -g https://www.youtube.com/watch?v=O1wH5h0NE8Y) -ar 16000 -y "/grand/EVITA/ben/AudioSet/unbalanced/videos/O1wH5h0NE8Y.mp4"
# Out:
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-2)
# ...

# %%
# %run process_unbalanced_1M.py download-all-multithreaded --offset 0
# Out:
# ...
# dst_dir: /grand/EVITA/ben/AudioSet/unbalanced/videos
# yt_id: NbFxSTa8wH8, start_seconds:  30.000, end_seconds:  40.000
# ffmpeg -ss  30.000 -t 10 -i $(yt-dlp -N 8 -f 'b' -g https://www.youtube.com/watch?v=NbFxSTa8wH8) -ar 16000 -y "/grand/EVITA/ben/AudioSet/unbalanced/videos/NbFxSTa8wH8.mp4"
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-2)
# ...

# %%
# %run find_missing_csv.py
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/code/audioset-processing-fix/find_missing_csv.py:23
#      21     for row in reader:
#      22         ytid = row[0]
# ---> 23         if not file_exists(ytid):  # Modified line
#      24             # If the file does not exist, write the row to the output CSV
#      25             writer.writerow(row)
#      27 print(f'Filtered CSV written to {output_csv_path}')
#
# File ~/code/audioset-processing-fix/find_missing_csv.py:10, in file_exists(ytid)
#       8 def file_exists(ytid):
#       9     file_path = os.path.join(directory_path, f'{ytid}.mp4')
# ---> 10     return os.path.isfile(file_path)
#
# File <frozen genericpath>:30, in isfile(path)
#
# KeyboardInterrupt:

# %%
# %run find_extra_csv.py
# Out:
# Extra videos CSV written to data/balanced_train_segments_extra.csv

# %%
cd /home/ben2002chou/code/cav-mae/src/preprocess
# Out:
# /home/ben2002chou/code/cav-mae/src/preprocess

# %%
# %run create_csv_balanced.py
